# %% [markdown]
# RESULTADOS OBTENIDOS COMPARANDO CON CRANFIELD

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# VECTORIAL

# %% [markdown]
# Se realizaron diferentes pruebas variando entre los valores del umbral

# %%
umbral = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# %% [markdown]
# Sin usar el lemantizador de nltk

# %%
acc = [11, 23, 37, 50, 64, 72, 75, 80, 82]
rec = [55, 41, 29, 19, 13, 9, 5, 3, 2]
f1 = [0.18, 0.29, 0.32, 0.28, 0.22, 0.16, 0.09, 0.07, 0.04]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, acc, label = 'Acc')
ax[0].plot(umbral, rec, label = 'Rec')
ax[1].plot(umbral, f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Usando lemantizador de nltk

# %%
accl = [10,19,31,42,53,62,71,77,80]
recl = [62,47,36,26,18,12,9,6,4]
f1l = [0.18, 0.27, 0.33, 0.32, 0.27, 0.20, 0.15, 0.11, 0.08]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, accl, label = 'Acc Lemant')
ax[0].plot(umbral, recl, label = 'Rec Lemant')
ax[1].plot(umbral, f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Comparacion

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, acc, label = 'Acc')
ax[0].plot(umbral, rec, label = 'Rec')
ax[1].plot(umbral, f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, accl, label = 'Acc Lemant')
ax[0].plot(umbral, recl, label = 'Rec Lemant')
ax[1].plot(umbral, f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# ANÁLISIS DE SEMÁNTICA LATENTE

# %% [markdown]
# Se realizaron unsa serie de pruebas combinando variaciones de diferentes umbrales con valores de 'k' y se obtuvieron los siguientes resultados:

# %%
umbral = [0.8, 0.7, 0.6, 0.5]

# %% [markdown]
# Para k = 50 sin lemantizador

# %%
k50Acc = [47, 35, 26, 18]
k50Rec = [17, 29, 40, 51]
k50f1 = [0.25, 0.32, 0.32, 0.27]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50Acc, label = 'Acc k = 50')
ax[0].plot(umbral, k50Rec, label = 'Rec k = 50')
ax[1].plot(umbral, k50f1, label = 'f1 k = 50')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 50 con lemantizador

# %%
k50accl = [46,35,26,17]
k50recl = [19,31,44,53]
k50f1l = [.27, .33, .33, .26]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50accl, label = 'Acc Lemant k = 50')
ax[0].plot(umbral, k50recl, label = 'Rec Lemant k = 50')
ax[1].plot(umbral, k50f1l, label = 'F1 Lemant k = 50')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Comparacion

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50Acc, label = 'Acc')
ax[0].plot(umbral, k50Rec, label = 'Rec')
ax[1].plot(umbral, k50f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k50accl, label = 'Acc Lemant')
ax[0].plot(umbral, k50recl, label = 'Rec Lemant')
ax[1].plot(umbral, k50f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Para k = 100 sin lemantizador

# %%
k100Acc = [69, 59, 47, 34]
k100Rec = [7, 16, 26, 38]
k100f1 = [.13, .25, .33, .36]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k100Acc, label = 'Acc k = 100')
ax[0].plot(umbral, k100Rec, label = 'Rec k = 100')
ax[1].plot(umbral, k100f1, label = 'F1 k = 100')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 100 con lemantizador

# %%
k100accl = [70,57,45,33]
k100recl = [9,19,29,40]
k100f1l = [.16, .29, .35, .36]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k100accl, label = 'Acc Lemant k = 100')
ax[0].plot(umbral, k100recl, label = 'Rec Lemant k = 100')
ax[1].plot(umbral, k100f1l, label = 'F1 Lemant k = 100')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Comparacion

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k100Acc, label = 'Acc')
ax[0].plot(umbral, k100Rec, label = 'Rec')
ax[1].plot(umbral, k100f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k100accl, label = 'Acc Lemant')
ax[0].plot(umbral, k100recl, label = 'Rec Lemant')
ax[1].plot(umbral, k100f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Para k = 150 sin lemantizador

# %%
k150Acc = [85, 74, 58, 45]
k150Rec = [4, 11, 18, 29]
k150f1 = [.08, .2, .27, .35]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k150Acc, label = 'Acc k = 150')
ax[0].plot(umbral, k150Rec, label = 'Rec k = 150')
ax[1].plot(umbral, k150f1, label = 'F1 k = 150')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 150 con lemantizador

# %%
k150accl = [84,70,58,43]
k150recl = [5,12,21,31]
k150f1l = [.1, .21, .31, .36]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k150accl, label = 'Acc Lemant k = 150')
ax[0].plot(umbral, k150recl, label = 'Rec Lemant k = 150')
ax[1].plot(umbral, k150f1l, label = 'F1 Lemant k = 150')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Comparacion

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k150Acc, label = 'Acc')
ax[0].plot(umbral, k150Rec, label = 'Rec')
ax[1].plot(umbral, k150f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k150accl, label = 'Acc Lemant')
ax[0].plot(umbral, k150recl, label = 'Rec Lemant')
ax[1].plot(umbral, k150f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Para k = 200 sin lemantizador

# %%
k200Acc = [89, 81, 68, 52]
k200Rec = [2, 7, 14, 22]
k200f1 = [.04, .13, .23, .31]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k200Acc, label = 'Acc k = 200')
ax[0].plot(umbral, k200Rec, label = 'Rec k = 200')
ax[1].plot(umbral, k200f1, label = 'F1 k = 200')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 200 con lemantizador

# %%
k200accl = [92, 81, 67, 52]
k200recl = [3, 8, 16, 25]
k200f1l = [.06, .14, .25, .33]

fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k200accl, label = 'Acc Lemant k = 200')
ax[0].plot(umbral, k200recl, label = 'Rec Lemant k = 200')
ax[1].plot(umbral, k200f1l, label = 'F1 Lemant k = 200')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Comparación

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k200Acc, label = 'Acc')
ax[0].plot(umbral, k200Rec, label = 'Rec')
ax[1].plot(umbral, k200f1, label = 'F1')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k200accl, label = 'Acc Lemant')
ax[0].plot(umbral, k200recl, label = 'Rec Lemant')
ax[1].plot(umbral, k200f1l, label = 'F1 Lemant')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Resumen de todos los gráficos sin lemantización:

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50Acc, label = 'Acc k = 50')
ax[0].plot(umbral, k50Rec, label = 'Rec k = 50')
ax[0].plot(umbral, k100Acc, label = 'Acc k = 100')
ax[0].plot(umbral, k100Rec, label = 'Rec k = 100')
ax[0].plot(umbral, k150Acc, label = 'Acc k = 150')
ax[0].plot(umbral, k150Rec, label = 'Rec k = 150')
ax[0].plot(umbral, k200Acc, label = 'Acc k = 200')
ax[0].plot(umbral, k200Rec, label = 'Rec k = 200')
ax[1].plot(umbral, k50f1, label = 'F1 k = 50')
ax[1].plot(umbral, k100f1, label = 'F1 k = 100')
ax[1].plot(umbral, k150f1, label = 'F1 k = 150')
ax[1].plot(umbral, k200f1, label = 'F1 k = 200')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Resumen de todos los gráficos con lemantización:

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50accl, label = 'Acc Lemant k = 50')
ax[0].plot(umbral, k50recl, label = 'Rec Lemant k = 50')
ax[0].plot(umbral, k100accl, label = 'Acc Lemant k = 100')
ax[0].plot(umbral, k100recl, label = 'Rec Lemant k = 100')
ax[0].plot(umbral, k150accl, label = 'Acc Lemant k = 150')
ax[0].plot(umbral, k150recl, label = 'Rec Lemant k = 150')
ax[0].plot(umbral, k200accl, label = 'Acc Lemant k = 200')
ax[0].plot(umbral, k200recl, label = 'Rec Lemant k = 200')
ax[1].plot(umbral, k50f1l, label = 'F1 Lemant k = 50')
ax[1].plot(umbral, k100f1l, label = 'F1 Lemant k = 100')
ax[1].plot(umbral, k150f1l, label = 'F1 Lemant k = 150')
ax[1].plot(umbral, k200f1l, label = 'F1 Lemant k = 200')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# VECTORIAL vs LSA vs BOOLEANO

# %%
maxF1Vec = max(f1l)
maxF1LSA = max([max(k50f1l), max(k100f1l), max(k150f1l), max(k200f1l)])

maxF = max(maxF1Vec, maxF1LSA)

print(f'El modelo con mayor media armónica F1 es: LSA con un valor de: {maxF}')
# Out:
# El modelo con mayor media armónica F1 es: LSA con un valor de: 0.36

# %% [markdown]
# Nota: No se usaron los pos_tags ya que disminuyó en gran medida pa precisión y el recobrado del modelo LSA:
#
# k = 150, umbral >= 0.5 : 32% precision, 22% recobrado
#
# k = 200, umbral >= 0.5 : 40% precision, 18% recobrado
#
# donde con solamente el lemantizador los valores son:
#
# k = 150, umbral >= 0.5 : 43% precision, 31% recobrado
#
# k = 200, umbral >= 0.5 : 52% precision, 25% recobrado
