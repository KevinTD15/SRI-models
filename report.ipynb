# %% [markdown]
# RESULTADOS OBTENIDOS COMPARANDO Con:
# CRANFIELD, VASWANI, CISI

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from statistics import mean

# %% [markdown]
# VECTORIAL

# %% [markdown]
# Se realizaron diferentes pruebas variando entre los valores del umbral

# %%
umbral = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# %% [markdown]
# Datos obtenidos de Cranfield:

# %%
accCran = [10,19,31,42,53,62,71,77,80]
reclCran = [62,47,36,26,18,12,9,6,4]
f1Cran = [0.18, 0.27, 0.33, 0.32, 0.27, 0.20, 0.15, 0.11, 0.08]

# %% [markdown]
# Datos obtenidos de CISI:

# %%
accCisi = [19,27,35,39,45,45,60,66,100]
reclCisi = [15,6,2,1,0.6,0.2,0.1,0.1,0.03]
f1Cisi = [0.17,0.1,0.05,0.02,0.01,0.003,0.002,0.001,0.001]

# %% [markdown]
# Datos obtenidos de Vaswani:

# %%
accVas = [5,8,13,17,20,23,22,24,24]
reclVas = [53,35,22,14,8,5,2,1,0.5]
f1Vas = [0.1,0.14,0.16,0.15,0.12,0.08,0.04,0.02,0.01]

# %% [markdown]
# COMPARACION ENTRE RESULTADOS PARA CADA DATASET:

# %% [markdown]
# Comparación de precisiones:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, accCran, label = 'Acc Cranfield')
ax.plot(umbral, accCisi, label = 'Acc Cisi')
ax.plot(umbral, accVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparacion de recobrado:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, reclCran, label = 'Rec Cranfield')
ax.plot(umbral, reclCisi, label = 'Rec Cisi')
ax.plot(umbral, reclVas, label = 'Rec Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación general:

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, accCran, label = 'Acc Cran')
ax[0].plot(umbral, reclCran, label = 'Rec Cran')
ax[1].plot(umbral, f1Cran, label = 'F1 Cran')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, accCisi, label = 'Acc Cisi')
ax[0].plot(umbral, reclCisi, label = 'Rec Cisi')
ax[1].plot(umbral, f1Cisi, label = 'F1 Cisi')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, accVas, label = 'Acc Vas')
ax[0].plot(umbral, reclVas, label = 'Rec Vas')
ax[1].plot(umbral, f1Vas, label = 'F1 Vas')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# ANÁLISIS DE SEMÁNTICA LATENTE

# %% [markdown]
# Nota:
#
# En este modelo solo se usará la mitad del corpus de Vaswani debido a la gran cantidad de documentos que este contiene

# %% [markdown]
# Se realizaron unsa serie de pruebas combinando variaciones de diferentes umbrales con valores de 'k' y se obtuvieron los siguientes resultados:

# %%
umbral = [0.8, 0.7, 0.6, 0.5]

# %% [markdown]
# Para k = 50

# %% [markdown]
# Datos obtenidos de Cranfield:

# %%
k50accCran = [46,35,26,17]
k50recCran = [19,31,44,53]
k50f1Cran = [.27, .33, .33, .26]

# %% [markdown]
# Datos obtenidos de Cisi:

# %%
k50accCisi = [38,26,21,16]
k50recCisi = [1,4,10,19]
k50f1Cisi = [.02,.07,.13,.17]

# %% [markdown]
# Datos obtenidos de Vaswani: ARREGLAR!!!!!!!!!!!!!!!!!!!

# %%
k50accVas = [12,8,8,6]
k50recVas = [3,10,23,38]
k50f1Vas = [.05,.1,.11,.1]

# %% [markdown]
# COMPARACIÓN DE RESULTADOS PARA CADA DATASET

# %% [markdown]
# Comparación de precisiones:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k50accCran, label = 'Acc Cranfield')
ax.plot(umbral, k50accCisi, label = 'Acc Cisi')
ax.plot(umbral, k50accVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación de recobrado:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k50recCran, label = 'Rec Cranfield')
ax.plot(umbral, k50recCisi, label = 'Rec Cisi')
ax.plot(umbral, k50recVas, label = 'Rec Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación general:

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k50accCran, label = 'Acc Cran')
ax[0].plot(umbral, k50recCran, label = 'Rec Cran')
ax[1].plot(umbral, k50f1Cran, label = 'F1 Cran')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k50accCisi, label = 'Acc Cisi')
ax[0].plot(umbral, k50recCisi, label = 'Rec Cisi')
ax[1].plot(umbral, k50f1Cisi, label = 'F1 Cisi')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k50accVas, label = 'Acc Vas')
ax[0].plot(umbral, k50recVas, label = 'Rec Vas')
ax[1].plot(umbral, k50f1Vas, label = 'F1 Vas')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 100

# %% [markdown]
# Datos obtenidos de Cranfield:

# %%
k100accCran = [70,57,45,33]
k100recCran = [9,19,29,40]
k100f1Cran = [.16, .29, .35, .36]

# %% [markdown]
# Datos obtenidos de Cisi:

# %%
k100accCisi = [66,43,38,30]
k100recCisi = [3,1,4,8]
k100f1Cisi = [.006,.2,.06,.13]

# %% [markdown]
# Datos obtenidos de Vaswani:

# %%
k100accVas = [29,18,14,9]
k100recVas = [1,3,10,19]
k100f1Vas = [.02,.06, .11, .13]

# %% [markdown]
# COMPARACIÓN DE RESULTADOS PARA CADA DATASET:

# %% [markdown]
# Comparación de precisiones

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k100accCran, label = 'Acc Cranfield')
ax.plot(umbral, k100accCisi, label = 'Acc Cisi')
ax.plot(umbral, k100accVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación de recobrado:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k100recCran, label = 'Acc Cranfield')
ax.plot(umbral, k100recCisi, label = 'Acc Cisi')
ax.plot(umbral, k100recVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación general:

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k100accCran, label = 'Acc Cran')
ax[0].plot(umbral, k100recCran, label = 'Rec Cran')
ax[1].plot(umbral, k100f1Cran, label = 'F1 Cran')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k100accCisi, label = 'Acc Cisi')
ax[0].plot(umbral, k100recCisi, label = 'Rec Cisi')
ax[1].plot(umbral, k100f1Cisi, label = 'F1 Cisi')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k100accVas, label = 'Acc Vas')
ax[0].plot(umbral, k100recVas, label = 'Rec Vas')
ax[1].plot(umbral, k100f1Vas, label = 'F1 Vas')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 150

# %% [markdown]
# Datos obtenidos de Cranfield:

# %%
k150accCran = [84,70,58,43]
k150recCran = [5,12,21,31]
k150f1Cran = [.1, .21, .31, .36]

# %% [markdown]
# Datos obtenidos de Cisi:

# %%
k150accCisi = [79, 51, 46, 28]
k150recCisi = [.4, .1, 2, 5]
k150f1Cisi = [.007, .06, .04, .09]

# %% [markdown]
# Datos obtenidos de Vaswani:

# %%
k150accVas = [25,29,14,12]
k150recVas = [.1, 2,4,12]
k150f1Vas = [.002, .03, .07, .12]

# %% [markdown]
# COMPARACIÓN DE RESULTADOS PARA CADA DATASET:

# %% [markdown]
# Comparación de precisiones

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k150accCran, label = 'Acc Cranfield')
ax.plot(umbral, k150accCisi, label = 'Acc Cisi')
ax.plot(umbral, k150accVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación de recobrado

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k150recCran, label = 'Acc Cranfield')
ax.plot(umbral, k150recCisi, label = 'Acc Cisi')
ax.plot(umbral, k150recVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación general

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k150accCran, label = 'Acc Cran')
ax[0].plot(umbral, k150recCran, label = 'Rec Cran')
ax[1].plot(umbral, k150f1Cran, label = 'F1 Cran')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k150accCisi, label = 'Acc Cisi')
ax[0].plot(umbral, k150recCisi, label = 'Rec Cisi')
ax[1].plot(umbral, k150f1Cisi, label = 'F1 Cisi')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k150accVas, label = 'Acc Vas')
ax[0].plot(umbral, k150recVas, label = 'Rec Vas')
ax[1].plot(umbral, k150f1Vas, label = 'F1 Vas')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# Para k = 200

# %% [markdown]
# Datos obtenidos de Cranfield:

# %%
k200accCran = [92, 81, 67, 52]
k200recCran = [3, 8, 16, 25]
k200f1Cran = [.06, .14, .25, .33]

# %% [markdown]
# Datos obtenidos de Cisi:

# %%
k200accCisi = [100,58,50,43]
k200recCisi = [.3,.6,.2,4]
k200f1Cisi = [.005,.11,.03,.07]

# %% [markdown]
# Datos obtenidos de Vaswani:

# %%
k200accVas = [0,28,19,12]
k200recVas = [0,1,3,7]
k200f1Vas = [0,.01,.05,1]

# %% [markdown]
# COMPARACIÓN DE RESULTADOS PARA CADA DATASET:

# %% [markdown]
# Comparación de precisiones:

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k200accCran, label = 'Acc Cranfield')
ax.plot(umbral, k200accCisi, label = 'Acc Cisi')
ax.plot(umbral, k200accVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación de recobrado

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (8, 6)
ax.plot(umbral, k200recCran, label = 'Acc Cranfield')
ax.plot(umbral, k200recCisi, label = 'Acc Cisi')
ax.plot(umbral, k200recVas, label = 'Acc Vaswani')
ax.legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
plt.show()

# %% [markdown]
# Comparación general

# %%
fig, ax = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (8, 6)
ax[0].plot(umbral, k200accCran, label = 'Acc Cran')
ax[0].plot(umbral, k200recCran, label = 'Rec Cran')
ax[1].plot(umbral, k200f1Cran, label = 'F1 Cran')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k200accCisi, label = 'Acc Cisi')
ax[0].plot(umbral, k200recCisi, label = 'Rec Cisi')
ax[1].plot(umbral, k200f1Cisi, label = 'F1 Cisi')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[0].plot(umbral, k200accVas, label = 'Acc Vas')
ax[0].plot(umbral, k200recVas, label = 'Rec Vas')
ax[1].plot(umbral, k200f1Vas, label = 'F1 Vas')
ax[0].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)
ax[1].legend(loc = 'best', bbox_to_anchor =(0.75, 1.15), ncol = 2)

plt.show()

# %% [markdown]
# BOOLEANO

# %% [markdown]
# Se realizaron pruebas haciendo uso de los tipos de consulta parcial y total (ver informe.pdf), y al igual que en el modelo LSA solo se usó la mitad del corpus de Vaswani por el mismo motivo

# %% [markdown]
# COMPARACIÓN DE RESULTADOS PARA CADA DATASET

# %% [markdown]
# CRANFIELD
#
# Total: 65% precision, 1% recobrado, F1: 0.02
#
# Parcial: 1% precision, 92% recobrado, F1: 0.02

# %% [markdown]
# CISI
#
# Total: 66% precision, 0.1% recobrado, F1: 0.002
#
# Parcial: 2% precision, 90% recobrado, F1: 0.04

# %% [markdown]
# VASWANI
#
# Total: 0% precision, 0% recobrado, F1: 0
#
# Parcial: 1% precision, 89% recobrado, F1: 0.02

# %% [markdown]
# VECTORIAL vs LSA vs BOOLEANO

# %%
maxF1Vec = mean(f1Cran + f1Cisi + f1Vas)
vecPrint = ('Vectorial', maxF1Vec)

maxF1LSA = mean(k50f1Cran + k100f1Cran + k150f1Cran + k200f1Cran +
                 k50f1Cisi + k100f1Cisi + k150f1Cisi + k200f1Cisi +
                 k50f1Vas + k100f1Vas + k150f1Vas + k200f1Vas)
lsaPrint = ('LSA', maxF1LSA)

maxF1Bool = mean([0.02, 0.02, 0.002, 0.04, 0, 0.02])
boolPrint = ('Booleano', maxF1Bool)

#result = [vecPrint, lsaPrint, boolPrint]

maxF = [vecPrint, lsaPrint, boolPrint]
maxF.sort(key=lambda x : x[1], reverse=True)
for i in maxF:
    print(f'Media de medidas F1 de {i[0]} es: {i[1]}')
# Out:
# Media de medidas F1 de LSA es: 0.15145833333333333
# Media de medidas F1 de Vectorial es: 0.11433333333333334
# Media de medidas F1 de Booleano es: 0.017

# %% [markdown]
# Nota: No se usaron los pos_tags ya que disminuyó en gran medida pa precisión y el recobrado del modelo LSA:
#
# Con pos_tags:
#
# k = 150, umbral >= 0.5 : 32% precision, 22% recobrado
#
# k = 200, umbral >= 0.5 : 40% precision, 18% recobrado
#
# Sin pos_tags:
#
# k = 150, umbral >= 0.5 : 43% precision, 31% recobrado
#
# k = 200, umbral >= 0.5 : 52% precision, 25% recobrado
